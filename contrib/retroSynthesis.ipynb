# %%
from aizynthfinder.aizynthfinder import AiZynthFinder, AiZynthExpander
import numpy as np
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem, Descriptors

# %%
filename = "./../data/config.yml"
finder = AiZynthFinder(configfile=filename)

# %%
finder.stock.select("zinc")
finder.expansion_policy.select("uspto")
finder.filter_policy.select("uspto")

# %%
moroidin = 'CC(C)CC1C(=O)NC(C(=O)NC2CC3=C(NC4=C3C=CC(=C4)C(C(C(=O)N1)NC(=O)C5CCC(=O)N5)C(C)C)N6C=C(CC(NC(=O)CNC(=O)C(NC2=O)CCC[NH+]=C(N)N)C(=O)[O-])N=C6)C(C)C'

# %%
finder.target_smiles = moroidin
finder.tree_search()
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# ...
# ...
# 1/1 [==============================] - 0s 15ms/step
# 410.24190878868103

# %%
finder.build_routes()
stats = finder.extract_statistics()

# %%
expander = AiZynthExpander(configfile=filename)
expander.expansion_policy.select("uspto")
expander.filter_policy.select("uspto")
reactions = expander.do_expansion(moroidin)
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step

# %%
reactants_smiles = []
for reaction_tuple in reactions:
    for mol in reaction_tuple[0].reactants:
        print(mol[0])
# Out:
# CC(C)CC1C(=O)NC(C(C)C)C(=O)NC2Cc3c([nH]c4cc(ccc34)C(C(C)C)C(NC(=O)C3CCC(=O)N3)C(=O)N1C(=O)OCc1ccccc1)-n1cnc(c1)CC(C(=O)[O-])NC(=O)CNC(=O)C(CCC[NH+]=C(N)N)NC2=O
# CC(C)CC1NC(=O)C(NC(=O)C2CCC(=O)N2)C(C(C)C)c2ccc3c(c(-n4cnc(CC(NC(=O)CNC(=O)C(N)CCC[NH+]=C(N)N)C(=O)[O-])c4)[nH]c3c2)CC(C(=O)O)NC(=O)C(C(C)C)NC1=O
# CC(C)CC1NC(=O)C(NC(=O)C2CCC(=O)N2)C(C(C)C)c2ccc3c4c([nH]c3c2)-n2cnc(c2)CC(C(=O)[O-])NC(=O)CNC(=O)C(CCC[NH+]=C(N)NC(=O)OC(C)(C)C)NC(=O)C(C4)NC(=O)C(C(C)C)NC1=O
# COC(=O)C(CCC[NH+]=C(N)N)NC(=O)C1Cc2c(-n3cnc(CC(NC(=O)CN)C(=O)[O-])c3)[nH]c3cc(ccc23)C(C(C)C)C(NC(=O)C2CCC(=O)N2)C(=O)NC(CC(C)C)C(=O)NC(C(C)C)C(=O)N1
# CC(C)CC1NC(=O)C(NC(=O)C2CCC(=O)N2)C(C(C)C)c2ccc3c4c(n(C(=O)OC(C)(C)C)c3c2)-n2cnc(c2)CC(C(=O)[O-])NC(=O)CNC(=O)C(CCC[NH+]=C(N)N)NC(=O)C(C4)NC(=O)C(C(C)C)NC1=O

# %%
metadata = []
for reaction_tuple in reactions:
    for reaction in reaction_tuple:
        metadata.append(reaction.metadata)
df = pd.DataFrame(metadata)

# %%
df
# Out:
#                                        template_hash        classification  \
# 0  df7bfcdfa354b67aca4d859f2d90009acc9338c20600e8...      NH deprotections
# 1  09e961e4c21b1adcf2f8d3b116773699ab5020ae114ca5...  N-acylation to amide
# 2  72603df4e97d739310a00a91bf1cf924b7b460c6ce033f...  N-acylation to amide
# 3  858d3f6799b8d478063dc2653483f88126c5a9adf9a5b8...  N-acylation to amide
# 4  9700dfbbea18932b10f40ed49527a6efd0b261364d0b5e...  N-acylation to amide
# 5  6c83f45f485301792011c63e6835be21ece3be24f5b32a...      NH deprotections
# 6  e26d17294107a39372b3ccdda4f0997f0c2c9ff90c5962...  N-acylation to amide
# 7  a8bcb727bba466525d939351bf42febfe55e3a61156507...      NH deprotections
#
#    library_occurence  policy_probability  policy_probability_rank policy_name  \
# 0                 15              0.2960                        0       uspto
# 1               1116              0.0280                        5       uspto
# ...
